# %% [markdown]
# ## Assignment 1: Interacting with PostgreSQL
#
# For this assignment, we're downloading the dataset to use for the rest of the class

# %%
import seaborn as sns
import pandas as pd

# %%
healthcare = pd.read_csv('archive/healthcare_dataset.csv')

# %%
healthcare.info
# Out:
# <bound method DataFrame.info of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %% [markdown]
# **Healthcare Dataset**
# This dataset consists of 15 columns
#
# |field_name|description|data_type|
# |---|---|---|
# |Name|Patient's name|Nominal|
# |Age|Age of patient at admission|Continuous|
# |Gender|Patient's Gender|Nominal|
# |Blood Type|Patient's blood type|Nominal|
# |Medical Condition|Primary Diagnosis|Nominal|
# |Date of Admission|Admission Date|Ordinal|
# |Doctor|Doctor responsible for patient|Nominal|
# |Hospital|Healtcare facility|Nominal|
# |Insurance Provider|Patient's insurance provider|Nominal|
# |Billing Amount|Total cost|Continuous|
# |Room Number|Patient room|Nominal|
# |Admission Type|Type of admission|Ordinal|
# |Discharge Date|Patient's discharge|Ordinal|
# |Medication|Medications prescribed during admission|Nominal|
# |Test Results|Results of medical tests|Ordinal|

# %%
healthcare.describe(include='all')
# Out:
#                Name           Age Gender Blood Type Medical Condition  \
# count         55500  55500.000000  55500      55500             55500
# unique        49992           NaN      2          8                 6
# top     DAvId muNoZ           NaN   Male         A-         Arthritis
# freq              3           NaN  27774       6969              9308
# mean            NaN     51.539459    NaN        NaN               NaN
# std             NaN     19.602454    NaN        NaN               NaN
# min             NaN     13.000000    NaN        NaN               NaN
# 25%             NaN     35.000000    NaN        NaN               NaN
# 50%             NaN     52.000000    NaN        NaN               NaN
# 75%             NaN     68.000000    NaN        NaN               NaN
# max             NaN     89.000000    NaN        NaN               NaN
#
#        Date of Admission         Doctor   Hospital Insurance Provider  \
# ...

# %%
healthcare.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %% [markdown]
# So what do we know?

# %% [markdown]
# ### Creating a new database and schema

# %%
healthcare.shape
# Out:
# (55500, 15)

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
host = r'127.0.0.1'
db = r'msds610'
user = r'postgres'
pw = r'Name11not!'
port = r'5432'
schema = r'raw'

# %%
db_conn = create_engine("postgresql://{}:{}@{}:{}/{}".format(user, pw, host, port, db))

# %% [markdown]
# Testing connection to the database.

# %%
sql="select tables.table_name from information_schema.tables where (table_schema ='"+schema+"')order by 1;"
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df
# Out:
#            table_name
# 0  healthcare_dataset

# %%
table_name = r'healthcare_dataset'

# %%
healthcare.to_sql(table_name, db_conn, if_exists='replace', index=False, schema=schema, chunksize=1000, method='multi')
# Out:
# 55500

# %%
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df
# Out:
#            table_name
# 0  healthcare_dataset

# %%
sql=r'SELECT * FROM '+schema+'.'+table_name
healthcare = pd.read_sql(sql, db_conn, index_col=None)

# %%
healthcare.head(10)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 0       Bobby JacksOn   30    Male         B-            Cancer
# 1        LesLie TErRy   62    Male         A+           Obesity
# 2         DaNnY sMitH   76  Female         A-           Obesity
# 3        andrEw waTtS   28  Female         O+          Diabetes
# 4       adrIENNE bEll   43  Female        AB+            Cancer
# 5       EMILY JOHNSOn   36    Male         A+            Asthma
# 6      edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7  CHrisTInA MARtinez   20  Female         A+            Cancer
# 8     JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9    ChRISTopher BerG   58  Female        AB-            Cancer
#
#   Date of Admission            Doctor                     Hospital  \
# 0        2024-01-31     Matthew Smith              Sons and Miller
# 1        2019-08-20   Samantha Davies                      Kim Inc
# ...

# %% [markdown]
# **Verifying through pgAdmin**

# %% [markdown]
# <img align="center" style="padding-left:5px;" src="archives/pgAdmin_verify.png" width=500><br>
